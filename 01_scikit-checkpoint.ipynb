# %% [markdown]
# # 8.1. Getting started with scikit-learn

# %%
import numpy as np
import scipy.stats as st
import sklearn.linear_model as lm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return np.exp(3 * x)

# %%
x_tr = np.linspace(0., 2, 200)
y_tr = f(x_tr)

# %%
x = np.array([0, .1, .2, .5, .8, .9, 1])
y = f(x) + 2 * np.random.randn(len(x))
y
# Out:
# array([ 1.66120145,  0.22215   ,  0.51480054,  5.19896958, 12.0605781 ,
#        20.65543196, 17.35105814])

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.plot(x_tr, y_tr, '--k')
ax.plot(x, y, 'ok', ms=10)
ax.set_xlim(0, 1.5)
ax.set_ylim(-10, 80)
ax.set_title('Generative model')
# Out:
# Text(0.5, 1.0, 'Generative model')

# %%
# We create the model.
lr = lm.LinearRegression()
# We train the model on our training dataset.
lr.fit(x[:, np.newaxis], y)
# Now, we predict points with our trained model.
y_lr = lr.predict(x_tr[:, np.newaxis])

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.plot(x_tr, y_tr, '--k')
ax.plot(x_tr, y_lr, 'g')
ax.plot(x, y, 'ok', ms=10)
ax.set_xlim(0, 1.5)
ax.set_ylim(-10, 80)
ax.set_title("Linear regression")
# Out:
# Text(0.5, 1.0, 'Linear regression')

# %%
lrp = lm.LinearRegression()
fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.plot(x_tr, y_tr, '--k')

for deg, s in zip([2, 5], ['-', '.']):
    lrp.fit(np.vander(x, deg + 1), y)
    y_lrp = lrp.predict(np.vander(x_tr, deg + 1))
    ax.plot(x_tr, y_lrp, s,
            label=f'degree {deg}')
    ax.legend(loc=2)
    ax.set_xlim(0, 1.5)
    ax.set_ylim(-10, 80)
    # Print the model's coefficients.
    print(f'Coefficients, degree {deg}:\n\t',
          ' '.join(f'{c:.2f}' for c in lrp.coef_))
ax.plot(x, y, 'ok', ms=10)
ax.set_title("Linear regression")
# Out:
# Coefficients, degree 2:
# 	 19.93 -0.45 0.00
# Coefficients, degree 5:
# 	 -1246.53 3033.32 -2548.71 873.65 -96.04 0.00
# Text(0.5, 1.0, 'Linear regression')

# %%
ridge = lm.RidgeCV()

fig, ax = plt.subplots(1, 1, figsize=(6, 3))
ax.plot(x_tr, y_tr, '--k')

for deg, s in zip([2, 5], ['-', '.']):
    ridge.fit(np.vander(x, deg + 1), y)
    y_ridge = ridge.predict(np.vander(x_tr, deg + 1))
    ax.plot(x_tr, y_ridge, s,
            label='degree ' + str(deg))
    ax.legend(loc=2)
    ax.set_xlim(0, 1.5)
    ax.set_ylim(-10, 80)
    # Print the model's coefficients.
    print(f'Coefficients, degree {deg}:',
          ' '.join(f'{c:.2f}' for c in ridge.coef_))

ax.plot(x, y, 'ok', ms=10)
ax.set_title("Ridge regression")
# Out:
# Coefficients, degree 2: 11.47 7.28 0.00
# Coefficients, degree 5: 2.52 2.96 3.43 3.87 3.83 0.00
# Text(0.5, 1.0, 'Ridge regression')

# %%
pip install --upgrade google-cloud-bigquery
# Out:
# Collecting google-cloud-bigquery
#   Downloading https://files.pythonhosted.org/packages/c3/41/36c9f4fbbcc2dce592677c429efc405cdfe880b5d3229e812a37e6be0e6c/google_cloud_bigquery-1.26.1-py2.py3-none-any.whl (170kB)
# Collecting google-api-core<2.0dev,>=1.21.0 (from google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/e0/2d/7c6c75013105e1d2b6eaa1bf18a56995be1dbc673c38885aea31136e9918/google_api_core-1.22.1-py2.py3-none-any.whl (91kB)
# Collecting google-resumable-media<2.0dev,>=0.5.0 (from google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/e9/8a/0c1653af6504dcf39c094585d760215f90c6a9d8491431372d684c885e45/google_resumable_media-0.7.1-py2.py3-none-any.whl (42kB)
# Collecting google-cloud-core<2.0dev,>=1.1.0 (from google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/a8/c8/9be9810356f62daea7e417164db6eb4b5f5edf087a9516fa4602de8b1924/google_cloud_core-1.4.1-py2.py3-none-any.whl
# Collecting six<2.0.0dev,>=1.13.0 (from google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in c:\users\prash\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2.22.0)
# Requirement already satisfied, skipping upgrade: setuptools>=34.0.0 in c:\users\prash\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (41.4.0)
# Collecting protobuf>=3.12.0 (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/6b/2e/28425c709c26525998be0b7a91c4090c87c38a1a9644fd43fefaea2e16c0/protobuf-3.13.0-cp37-cp37m-win_amd64.whl (1.0MB)
# Collecting google-auth<2.0dev,>=1.19.1 (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/0f/79/4c59796bb02535aee5e5d2e2c5e16008aaf48903c2ec2ff566a2774bb3e0/google_auth-1.20.1-py2.py3-none-any.whl (91kB)
# Requirement already satisfied, skipping upgrade: pytz in c:\users\prash\anaconda3\lib\site-packages (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2019.3)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0 (from google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/03/74/3956721ea1eb4bcf7502a311fdaa60b85bd751de4e57d1943afe9b334141/googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100kB)
# Collecting google-crc32c<0.2dev,>=0.1.0; python_version >= "3.5" (from google-resumable-media<2.0dev,>=0.5.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/62/a6/4ea4a92622ba5e9c54f648e4c390fc3c1a48fe5b121c13eb59652e24aad9/google_crc32c-0.1.0-cp37-cp37m-win_amd64.whl
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\prash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (1.24.2)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\prash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2019.9.11)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\prash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\prash\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery) (2.8)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2.0dev,>=1.19.1->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/cd/5c/f3aa86b6d5482f3051b433c7616668a9b96fbe49a622210e2c9781938a5c/cachetools-4.1.1-py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2.0dev,>=1.19.1->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.5" (from google-auth<2.0dev,>=1.19.1->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/1c/df/c3587a667d6b308fadc90b99e8bc8774788d033efcc70f4ecaae7fad144b/rsa-4.6-py3-none-any.whl (47kB)
# Requirement already satisfied, skipping upgrade: cffi>=1.0.0 in c:\users\prash\anaconda3\lib\site-packages (from google-crc32c<0.2dev,>=0.1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.5.0->google-cloud-bigquery) (1.12.3)
# Collecting pyasn1<0.5.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.19.1->google-api-core<2.0dev,>=1.21.0->google-cloud-bigquery)
#   Downloading https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77kB)
# Requirement already satisfied, skipping upgrade: pycparser in c:\users\prash\anaconda3\lib\site-packages (from cffi>=1.0.0->google-crc32c<0.2dev,>=0.1.0; python_version >= "3.5"->google-resumable-media<2.0dev,>=0.5.0->google-cloud-bigquery) (2.19)
# Installing collected packages: six, protobuf, cachetools, pyasn1, pyasn1-modules, rsa, google-auth, googleapis-common-protos, google-api-core, google-crc32c, google-resumable-media, google-cloud-core, google-cloud-bigquery
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
# Successfully installed cachetools-4.1.1 google-api-core-1.22.1 google-auth-1.20.1 google-cloud-bigquery-1.26.1 google-cloud-core-1.4.1 google-crc32c-0.1.0 google-resumable-media-0.7.1 googleapis-common-protos-1.52.0 protobuf-3.13.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.6 six-1.15.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: fbprophet 0.6 requires cmdstanpy==0.4, which is not installed.
# ERROR: fbprophet 0.6 requires setuptools-git>=1.2, which is not installed.
# ERROR: astroid 2.3.1 requires typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8", which is not installed.
# ERROR: astroid 2.3.1 has requirement six==1.12, but you'll have six 1.15.0 which is incompatible.

# %%
from google.cloud import bigquery
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-1035661e8528> in <module>
# ----> 1 from google.cloud import bigquery
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\__init__.py in <module>
#      33 __version__ = get_distribution("google-cloud-bigquery").version
#      34
# ---> 35 from google.cloud.bigquery.client import Client
#      36 from google.cloud.bigquery.dataset import AccessEntry
#      37 from google.cloud.bigquery.dataset import Dataset
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\client.py in <module>
#      58 from google.cloud.bigquery._helpers import _del_sub_prop
#      59 from google.cloud.bigquery._http import Connection
# ---> 60 from google.cloud.bigquery import _pandas_helpers
#      61 from google.cloud.bigquery.dataset import Dataset
#      62 from google.cloud.bigquery.dataset import DatasetListItem
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in <module>
#      39     pyarrow = None
#      40
# ---> 41 from google.cloud.bigquery import schema
#      42
#      43
#
# ~\Anaconda3\lib\site-packages\google\cloud\bigquery\schema.py in <module>
#      15 """Schemas for BigQuery tables / queries."""
#      16
# ---> 17 from six.moves import collections_abc
#      18
#      19 from google.cloud.bigquery_v2 import types
#
# ImportError: cannot import name 'collections_abc' from 'six.moves' (unknown location)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6f17b8178697> in <module>
# ----> 1 print(six.__version__)
#
# NameError: name 'six' is not defined
